# %%
import requests as req
import pandas as pd
from bs4 import BeautifulSoup as bs
from flask import Flask # 플라스크 클래스 임포트
from flask import request, redirect
import pickle # 데이터 저장/로딩을 위한 모듈
import pandas as pd
import numpy as np

# %%
def func():
    res = req.get('https://www.acmicpc.net/problem/1001')
    soup = bs(res.text,"lxml")
    list1 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(3)')
    list2 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(4)')
    list3 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(5)')
    list4 =soup.select('#problem-body')

    body=list1+list2+list3+list4
    result = ""
    for s in body:
        result += str(s)
    return result

# %%
# !pip install flask_cors

# %%
# print(body[0])
body[0].string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-f586f4dca77e> in <module>
#       1 # print(body[0])
# ----> 2 body[0].strings()
#
# TypeError: 'generator' object is not callable

# %%
import random

# %%
def func():
    
     while  soup.select('#problem-info > tbody > tr > td:nth-of-type(6)') > 80:
        
        res = req.get('https://www.acmicpc.net/problem/10'+str(randint(10,99)))
        soup = bs(res.text,"lxml")
        list1 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(3)')
        list2 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(4)')
        list3 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(5)')
        list4 =soup.select('#problem-body') 

        body=list1+list2+list3+list4
    
    
    
    
    
    
    
   
        result = ""
        for s in body:
            result += str(s)
        return result

# %%
while  soup.select('#problem-info > tbody > tr > td:nth-of-type(6)') > 80:
        
        res = req.get('https://www.acmicpc.net/problem/10'+str(randint(10,99)))
        soup = bs(res.text,"lxml")
        list1 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(3)')
        list2 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(4)')
        list3 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(5)')
        list4 =soup.select('#problem-body') 

        body=list1+list2+list3+list4
    
    
    
    
    
    
    
   
        result = ""
        for s in body:
            result += str(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-f394beaecd35> in <module>
# ----> 1 while  int(soup.select('#problem-info > tbody > tr > td:nth-of-type(6)')) > 80:
#       2
#       3         res = req.get('https://www.acmicpc.net/problem/10'+str(randint(10,99)))
#       4         soup = bs(res.text,"lxml")
#       5         list1 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(3)')
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
re=soup.select('#problem-info > tbody > tr > td:nth-of-type(6)')
for i in re :
    print(i.text)
# Out:
# 72.096%

# %%
        
        res = req.get('https://www.acmicpc.net/problem/10'+str(random.randint(10,99)))
        soup = bs(res.text,"lxml")
        list1 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(3)')
        list2 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(4)')
        list3 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(5)')
        list4 =soup.select('#problem-body') 

        body=list1+list2+list3+list4
    
    
    
    
    
    
    
   
        result = ""
        for s in body:
            result += str(s)

# %%
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000002A52C89BB40>>

# %%
soup.select('#problemset > tbody > tr:nth-of-type(1) > td:nth-of-type(6)')
#problemset > tbody > tr:nth-child(2) > td:nth-child(6)
# Out:
# []

# %%
res = req.get('https://www.acmicpc.net/problemset/'+str(random.randint(1,22)))
soup = bs(res.text,"lxml")

# %%
(dis)
# Out:
# '[<td>9.091%</td>]'

# %%
str(random.randint(10,99))
print(str(random.randint(10,99)))
# Out:
# 52

# %%
'https://www.acmicpc.net/problemset/'+str(random.randint(1,22))
#problemset > tbody > tr:nth-child(100) > td:nth-child(6)
# Out:
# 'https://www.acmicpc.net/problemset/1'

# %%
li_index = []
li_answerPer = []

res = req.get('https://www.acmicpc.net/problemset/'+str(random.randint(1,22)))
soup = bs(res.text,"lxml")
for i in range(1,100):
    
    answerPer = soup.select('#problemset > tbody > tr:nth-of-type('+str(i)+') > td:nth-of-type(6)')
    index = soup.select('#problemset > tbody > tr:nth-of-type('+str(i)+') > td.list_problem_id')

    str1 = index[0].text
    str2 = answerPer[0].text.replace("%","")
    
    li_index.append(str1)
    li_answerPer.append(str2)
    

    
    

unique = []

for i in range(len(li_index)):
    per = li_answerPer[i]
    if float(per) > 20.00:
       
        unique.append(li_index[i])
        

rndIndex = random.randrange(0, len(unique))
# print(rndIndex)

print(unique[rndIndex])

res2 = req.get('https://www.acmicpc.net/problem/'+str(unique[rndIndex]))
soup2 = bs(res2.text,"lxml")
list1 =soup2.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(3)')
list2 =soup2.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(4)')
list3 =soup2.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(5)')
list4 =soup2.select('#problem-body') 

body=list1+list2+list3+list4


result = ""
for s in body:
    result += str(s)
    

    
result
# Out:
# 2851
# ...

# %%
list4
# Out:
# [<div id="problem-body">
#  <div class="col-md-12">
#  <section class="problem-section" id="description">
#  <div class="headline">
#  <h2>문제</h2>
#  </div>
#  <div class="problem-text" id="problem_description">
#  <p>슈퍼 마리오 앞에 10개의 버섯이 일렬로 놓여져 있다. 이 버섯을 먹으면 점수를 받는다.</p>
#  <p>슈퍼 마리오는 버섯을 처음부터 나온 순서대로 집으려고 한다. 하지만, 모든 버섯을 집을 필요는 없고 중간에 중단할 수 있다. 중간에 버섯을 먹는 것을 중단했다면, 그 이후에 나온 버섯은 모두 먹을 수 없다. 따라서 첫 버섯을 먹지 않았다면, 그 이후 버섯도 모두 먹을 수 없다.</p>
#  <p>마리오는 받은 점수의 합을 최대한 100에 가깝게 만들려고 한다.</p>
#  <p>버섯의 점수가 주어졌을 때, 마리오가 받는 점수를 출력하는 프로그램을 작성하시오.</p>
#  </div>
#  </section>
#  </div>
#  <div class="col-md-12">
#  <section class="problem-section" id="input">
#  <div class="headline">
#  <h2>입력</h2>
#  </div>
#  <div class="problem-text" id="problem_input">
#  <p>총 10개의 줄에 각각의 버섯의 점수가 주어진다. 이 값은 100보다 작거나 같은 양의 정수이다. 버섯이 나온 순서대로 점수가 주어진다.</p>
#  </div>
#  </section>
#  </div>
#  <div class="col-md-12">
#  <section class="problem-section" id="output">
#  <div class="headline">
#  <h2>출력</h2>
#  </div>
# ...

# %%
len(li_index)
# Out:
# 99

# %%
str(unique[rndIndex])
# Out:
# '2969'

# %%
print(random.randrange(1,3))
# Out:
# 1

# %%
if

# %%
dis
# Out:
# [<td>78.769%</td>]

# %%
res = req.get('https://www.acmicpc.net/problem/1001')
soup = bs(res.text,"lxml")

# %%
arr2 = []

for i in range(1,100):
    
    dis1 = soup.select('#problemset > tbody > tr:nth-of-type('+str(i)+') > td.list_problem_id')
    str2 = dis1[0]
    
    str2 = str2.replace('<td class="list_problem_id">','')
    str2 = str2.replace("</td>","")
    arr2.append(str2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-0ff23b0b3efb> in <module>
#       4
#       5     dis1 = soup.select('#problemset > tbody > tr:nth-of-type('+str(i)+') > td.list_problem_id')
# ----> 6     str2 = dis1[0]
#       7
#       8     str2 = str2.replace('<td class="list_problem_id">','')
#
# IndexError: list index out of range

# %%
dis1
# Out:
# [<td class="list_problem_id">1200</td>]

# %%
li_index = []

    
li_answerPer = []


res = req.get('https://www.acmicpc.net/problemset/'+str(random.randint(1,13)))

soup = bs(res.text,"lxml")

for i in range(1,100):
    try:
        answerPer = soup.select('#problemset > tbody > tr:nth-of-type('+str(i)+') > td:nth-of-type(6)')
        index = soup.select('#problemset > tbody > tr:nth-of-type('+str(i)+') > td.list_problem_id')

        str1 = index[0].text
        str2 = answerPer[0].text.replace("%","")
    
        li_index.append(str1)
        li_answerPer.append(str2)
    except:
        pass


    
unique = []

for i in range(len(li_index)):
    
        per = li_answerPer[i]
        if float(per) > 10.00:
       
            unique.append(li_index[i])
        

rndIndex = random.randrange(0, len(unique))
# print(rndIndex)



#랜덤 추출
res2 = req.get('https://www.acmicpc.net/problem/'+str(unique[rndIndex]))
soup2 = bs(res2.text,"lxml")

list1 =soup2.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(3)')
list2 =soup2.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(4)')

list3 =soup2.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(5)')
list4 =soup2.select('#problem-body') 


body=list1+list2+list3+list4




result = ""
for s in body:
    result += str(s)

result
# Out:
# 16
# ...

# %%
list1
# Out:
# [<div class="col-md-12">
#  <div class="page-header">
#  <h1><span class="printable">
#  	2243번
#   - </span><span id="problem_title">사탕상자</span>
#  <div class="btn-group pull-right problem-button">
#  </div>
#  </h1>
#  </div>
#  </div>]

# %%
   
    
unique = []

for i in range(len(li_index)):
    
        per = li_answerPer[i]
        if float(per) > 20.00:
       
            unique.append(li_index[i])
        

rndIndex = random.randrange(0, len(unique))
# print(rndIndex)

    
#랜덤 추출
res2 = req.get('https://www.acmicpc.net/problem/'+str(unique[rndIndex]))
soup2 = bs(res2.text,"lxml")
list1 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(3)')
list2 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(4)')
list3 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(5)')
list4 =soup.select('#problem-body') 

body=list1+list2+list3+list4


result = ""
for s in body:
    result += str(s)

result
# Out:
# '<div class="margin-bottom-20"></div><div class="no-print" style="width: 100%;">\n<script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>\n<ins class="adsbygoogle" data-ad-client="ca-pub-8806842758252812" data-ad-format="auto" data-ad-slot="1129585289" style="display:block;"></ins>\n<script>\n(adsbygoogle = window.adsbygoogle || []).push({});\n</script>\n</div><div class="margin-bottom-20 no-print"></div>'

# %%
res2 = req.get('https://www.acmicpc.net/problem/1075')
soup2 = bs(res2.text,"lxml")
list1 =soup.select('body > div.wrapper > div.container.content > div.row > div:nth-of-type(3)')

# %%
list1
# Out:
# [<div class="margin-bottom-20"></div>]

# %%
random.randint(1,13)
# Out:
# 9
